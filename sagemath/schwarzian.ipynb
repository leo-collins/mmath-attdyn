# %%
var("μ x")
# Out:
# (μ, x)

# %%
f(x)=-2*pi*sin(x)

# %%
g(x)=((f.derivative(x,3)/f.derivative(x,1))-(3/2)*(f.derivative(x,2)/f.derivative(x))^2).factor().trig_reduce()

# %%
g(x)
# Out:
# 1/4*cos(2*x)*sec(x)^2 - 5/4*sec(x)^2

# %%
g(x).factor().trig_reduce()
# Out:
# 1/4*(cos(2*x) - 5)*sec(x)^2

# %%
plot(1/4*(cos(2*x) - 5)*sec(x)^2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
2+2
# Out:
# 4

# %%
f(x)=x^2

# %%
f
# Out:
# x |--> x^2

# %%
g(y)=2*y-1

# %%
g(10)
# Out:
# 19

# %%
plot(f, (x,-3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f.integrate(x)
# Out:
# x |--> 1/3*x^3

# %%
f.integrate?

# %%
binomial?

# %%
binomial??

# %%
z = (x+1)^3

# %%
z
# Out:
# (x + 1)^3

# %%
z.expand()
# Out:
# x^3 + 3*x^2 + 3*x + 1

# %%
show(z)
# Out:
# (x + 1)^3

# %%
z.simplify_full?

# %%
solve(z==0,x)
# Out:
# [x == -1]

# %%
var("ε")
# Out:
# ε

# %%
var("a,b,c,d,A,y,d1,d2,α,ϵ")
# Out:
# (a, b, c, d, A, y, d1, d2, α, ϵ)

# %%
J = matrix([[a-2*d1*A-y^2, b-2*ε*y, -2*d1*ε],[c+y^2, d-2*d2*A+2*ε*y, -2*d2*y],[-2*α*ε*(1-A),0,0]])

# %%
α
# Out:
# α

# %%
ε
# Out:
# ε

# %%
J
# Out:
# [  -2*A*d1 - y^2 + a          -2*y*ε + b             -2*d1*ε]
# [            y^2 + c -2*A*d2 + 2*y*ε + d             -2*d2*y]
# [      2*(A - 1)*α*ε                   0                   0]

# %%
f = J.characteristic_polynomial()

# %%
f
# Out:
# x^3 + (2*A*d1 + 2*A*d2 + y^2 - 2*y*ε - a - d)*x^2 + (4*A*d1*α*ε^2 + 4*A^2*d1*d2 + 2*A*d2*y^2 - 4*A*d1*y*ε - 4*d1*α*ε^2 - 2*A*d*d1 - 2*A*a*d2 - b*y^2 - d*y^2 + 2*a*y*ε + 2*c*y*ε - b*c + a*d)*x + 8*A^2*d1*d2*α*ε^2 - 8*A*d2*y^2*α*ε^2 - 8*A*d1*y*α*ε^3 + 4*A*b*d2*y*α*ε - 4*A*d*d1*α*ε^2 - 8*A*d1*d2*α*ε^2 + 8*d2*y^2*α*ε^2 + 8*d1*y*α*ε^3 - 4*b*d2*y*α*ε + 4*d*d1*α*ε^2

# %%
f.roots()
# Out:
# [(-2/3*A*(d1 + d2) - 1/3*y^2 + 2/3*y*ε + 1/18*(12*A^2*d1*d2 - 12*d1*α*ε^2 - 3*d*y^2 + 6*c*y*ε - (2*A*(d1 + d2) + y^2 - 2*y*ε - a - d)^2 + 6*(d2*y^2 + 2*(α*ε^2 - y*ε)*d1 - d*d1 - a*d2)*A + 3*(2*y*ε + d)*a - 3*(y^2 + c)*b)*(-I*sqrt(3) + 1)/(-4*A^2*d1*d2*α*ε^2 - 4*d2*y^2*α*ε^2 - 4*d1*y*α*ε^3 + 2*b*d2*y*α*ε - 2*d*d1*α*ε^2 - 1/27*(2*A*(d1 + d2) + y^2 - 2*y*ε - a - d)^3 + 1/6*(4*A^2*d1*d2 - 4*d1*α*ε^2 - d*y^2 + 2*c*y*ε + 2*(d2*y^2 + 2*(α*ε^2 - y*ε)*d1 - d*d1 - a*d2)*A + (2*y*ε + d)*a - (y^2 + c)*b)*(2*A*(d1 + d2) + y^2 - 2*y*ε - a - d) + 2*(2*d2*y^2*α*ε^2 - b*d2*y*α*ε + d*d1*α*ε^2 + 2*(y*α*ε^3 + d2*α*ε^2)*d1)*A + 1/6*sqrt(-16/3*A^4*d^2*d1^4 - 1/3*(4*A^2*d2^2 + b^2 + 2*b*d + d^2 - 4*(A*b + A*d)*d2)*y^8 + 2/3*(8*A^3*d2^3 + a*b^2 - 2*b^3 - b^2*c + 2*(a - 2*b)*d^2 - d^3 - 4*(4*A^3*d1 - 2*A^2*a + 4*A^2*b + 3*A^2*d)*d2^2 + (3*a*b - 5*b^2 - b*c)*d - 2*(A*b^2 + 3*A*b*d + 2*A*d^2)*d1 - 2*(3*A*a*b - 5*A*b^2 - A*b*c - 3*A*d^2 + 4*(A*a - 2*A*b)*d - 2*(3*A^2*b + 4*A^2*d)*d1)*d2)*y^6 + 256/3*((A - 1)*d1
# ...

# %%
J.eigenvalues()
# Out:
# [-2/3*A*(d1 + d2) - 1/3*y^2 + 2/3*y*ε + 1/18*(12*A^2*d1*d2 - 12*d1*α*ε^2 - 3*d*y^2 + 6*c*y*ε - (2*A*(d1 + d2) + y^2 - 2*y*ε - a - d)^2 + 6*(d2*y^2 + 2*(α*ε^2 - y*ε)*d1 - d*d1 - a*d2)*A + 3*(2*y*ε + d)*a - 3*(y^2 + c)*b)*(-I*sqrt(3) + 1)/(-4*A^2*d1*d2*α*ε^2 - 4*d2*y^2*α*ε^2 - 4*d1*y*α*ε^3 + 2*b*d2*y*α*ε - 2*d*d1*α*ε^2 - 1/27*(2*A*(d1 + d2) + y^2 - 2*y*ε - a - d)^3 + 1/6*(4*A^2*d1*d2 - 4*d1*α*ε^2 - d*y^2 + 2*c*y*ε + 2*(d2*y^2 + 2*(α*ε^2 - y*ε)*d1 - d*d1 - a*d2)*A + (2*y*ε + d)*a - (y^2 + c)*b)*(2*A*(d1 + d2) + y^2 - 2*y*ε - a - d) + 2*(2*d2*y^2*α*ε^2 - b*d2*y*α*ε + d*d1*α*ε^2 + 2*(y*α*ε^3 + d2*α*ε^2)*d1)*A + 1/6*sqrt(-16/3*A^4*d^2*d1^4 - 1/3*(4*A^2*d2^2 + b^2 + 2*b*d + d^2 - 4*(A*b + A*d)*d2)*y^8 + 2/3*(8*A^3*d2^3 + a*b^2 - 2*b^3 - b^2*c + 2*(a - 2*b)*d^2 - d^3 - 4*(4*A^3*d1 - 2*A^2*a + 4*A^2*b + 3*A^2*d)*d2^2 + (3*a*b - 5*b^2 - b*c)*d - 2*(A*b^2 + 3*A*b*d + 2*A*d^2)*d1 - 2*(3*A*a*b - 5*A*b^2 - A*b*c - 3*A*d^2 + 4*(A*a - 2*A*b)*d - 2*(3*A^2*b + 4*A^2*d)*d1)*d2)*y^6 + 256/3*((A - 1)*d1*
# ...

# %%
f(x) = J.characteristic_polynomial(x)

# %%
f(x)
# Out:
# 8*A^2*d1*d2*α*ε^2 - 8*A*d2*y^2*α*ε^2 - 8*A*d1*y*α*ε^3 + 4*A*b*d2*y*α*ε - 4*A*d*d1*α*ε^2 - 8*A*d1*d2*α*ε^2 + 8*d2*y^2*α*ε^2 + 8*d1*y*α*ε^3 - 4*b*d2*y*α*ε + 4*d*d1*α*ε^2 + (2*A*d1 + 2*A*d2 + y^2 - 2*y*ε - a - d)*x^2 + x^3 + (4*A*d1*α*ε^2 + 4*A^2*d1*d2 + 2*A*d2*y^2 - 4*A*d1*y*ε - 4*d1*α*ε^2 - 2*A*d*d1 - 2*A*a*d2 - b*y^2 - d*y^2 + 2*a*y*ε + 2*c*y*ε - b*c + a*d)*x

# %%
var("c2 c1 c0")
# Out:
# (c2, c1, c0)

# %%
c2 = (2*A*d1 + 2*A*d2 + y^2 - 2*y*ε - a - d)

# %%
c1 = (4*A*d1*α*ε^2 + 4*A^2*d1*d2 + 2*A*d2*y^2 - 4*A*d1*y*ε - 4*d1*α*ε^2 - 2*A*d*d1 - 2*A*a*d2 - b*y^2 - d*y^2 + 2*a*y*ε + 2*c*y*ε - b*c + a*d)

# %%
c0 = 8*A^2*d1*d2*α*ε^2 - 8*A*d2*y^2*α*ε^2 - 8*A*d1*y*α*ε^3 + 4*A*b*d2*y*α*ε - 4*A*d*d1*α*ε^2 - 8*A*d1*d2*α*ε^2 + 8*d2*y^2*α*ε^2 + 8*d1*y*α*ε^3 - 4*b*d2*y*α*ε + 4*d*d1*α*ε^2

# %%
f.solve(x)[0]
# Out:
# x == -2/3*A*(d1 + d2) - 1/3*y^2 + 2/3*y*ε + 1/18*(12*A^2*d1*d2 - 12*d1*α*ε^2 - 3*d*y^2 + 6*c*y*ε - (2*A*(d1 + d2) + y^2 - 2*y*ε - a - d)^2 + 6*(d2*y^2 + 2*(α*ε^2 - y*ε)*d1 - d*d1 - a*d2)*A + 3*(2*y*ε + d)*a - 3*(y^2 + c)*b)*(-I*sqrt(3) + 1)/(-4*A^2*d1*d2*α*ε^2 - 4*d2*y^2*α*ε^2 - 4*d1*y*α*ε^3 + 2*b*d2*y*α*ε - 2*d*d1*α*ε^2 - 1/27*(2*A*(d1 + d2) + y^2 - 2*y*ε - a - d)^3 + 1/6*(4*A^2*d1*d2 - 4*d1*α*ε^2 - d*y^2 + 2*c*y*ε + 2*(d2*y^2 + 2*(α*ε^2 - y*ε)*d1 - d*d1 - a*d2)*A + (2*y*ε + d)*a - (y^2 + c)*b)*(2*A*(d1 + d2) + y^2 - 2*y*ε - a - d) + 2*(2*d2*y^2*α*ε^2 - b*d2*y*α*ε + d*d1*α*ε^2 + 2*(y*α*ε^3 + d2*α*ε^2)*d1)*A + 1/6*sqrt(-16/3*A^4*d^2*d1^4 - 1/3*(4*A^2*d2^2 + b^2 + 2*b*d + d^2 - 4*(A*b + A*d)*d2)*y^8 + 2/3*(8*A^3*d2^3 + a*b^2 - 2*b^3 - b^2*c + 2*(a - 2*b)*d^2 - d^3 - 4*(4*A^3*d1 - 2*A^2*a + 4*A^2*b + 3*A^2*d)*d2^2 + (3*a*b - 5*b^2 - b*c)*d - 2*(A*b^2 + 3*A*b*d + 2*A*d^2)*d1 - 2*(3*A*a*b - 5*A*b^2 - A*b*c - 3*A*d^2 + 4*(A*a - 2*A*b)*d - 2*(3*A^2*b + 4*A^2*d)*d1)*d2)*y^6 + 256/3*((A - 1)
# ...
